# %%
from smac.env import StarCraft2Env
import numpy as np


def main():
    env = StarCraft2Env(map_name="8m")
    env_info = env.get_env_info()

    n_actions = env_info["n_actions"]
    n_agents = env_info["n_agents"]

    n_episodes = 1000

    for e in range(n_episodes):
        env.reset()
        terminated = False
        episode_reward = 0

        while not terminated:
            obs = env.get_obs()
            state = env.get_state()
            # env.render()  # Uncomment for rendering

            actions = []
            for agent_id in range(n_agents):
                avail_actions = env.get_avail_agent_actions(agent_id)
                avail_actions_ind = np.nonzero(avail_actions)[0]
                action = np.random.choice(avail_actions_ind)
                actions.append(action)

            reward, terminated, _ = env.step(actions)
            episode_reward += reward

        print("Total reward in episode {} = {}".format(e, episode_reward))

    env.close()

# %%
main()
# Out:
# Version: B75689 (SC2.4.10)
# Build: Aug 12 2019 17:16:57
# Command Line: '"/home/michael/StarCraftII/Versions/Base75689/SC2_x64" -listen 127.0.0.1 -port 46833 -dataDir /home/michael/StarCraftII/ -tempDir /tmp/sc-ud2_kpaf/'
# Starting up...
# Startup Phase 1 complete
# Startup Phase 2 complete
# Creating stub renderer...
# Listening on: 127.0.0.1:46833
# Startup Phase 3 complete. Ready for commands.
# ConnectHandler: Request from 127.0.0.1:54662 accepted
# ReadyHandler: 127.0.0.1:54662 ready
# Requesting to join a single player game
# Configuring interface options
# Configure: raw interface enabled
# Configure: feature layer interface disabled
# Configure: score interface disabled
# Configure: render interface disabled
# Launching next game.
# Next launch phase started: 2
# Next launch phase started: 3
# Next launch phase started: 4
# Next launch phase started: 5
# Next launch phase started: 6
# Next launch phase started: 7
# Next launch phase started: 8
# Game has started.
# Using default stable ids, none found at: /home/michael/StarCraftII/stableid.json
# Successfully loaded stable ids: GameData\stableid.json
# Sending ResponseJoinGame
# Total reward in episode 0 = 1.5
# Total reward in episode 1 = 1.6875
# Total reward in episode 2 = 1.875
# Total reward in episode 3 = 1.5
# Total reward in episode 4 = 1.875
# Total reward in episode 5 = 1.875
# Total reward in episode 6 = 1.6875
# Total reward in episode 7 = 2.0625
# Total reward in episode 8 = 1.5
# Total reward in episode 9 = 1.3125
# Total reward in episode 10 = 2.25
# Total reward in episode 11 = 1.5
# Total reward in episode 12 = 1.3125
# Total reward in episode 13 = 2.4375
# Total reward in episode 14 = 2.0625
# Total reward in episode 15 = 1.5
# Total reward in episode 16 = 1.5
# Total reward in episode 17 = 1.5
# Total reward in episode 18 = 1.3125
# Total reward in episode 19 = 1.875
# Total reward in episode 20 = 2.4375
# Total reward in episode 21 = 1.6875
# Total reward in episode 22 = 1.5
# Total reward in episode 23 = 2.0625
# Total reward in episode 24 = 1.875
# Total reward in episode 25 = 2.4375
# Total reward in episode 26 = 1.5
# Total reward in episode 27 = 2.0625
# Total reward in episode 28 = 1.6875
# Total reward in episode 29 = 1.875
# Total reward in episode 30 = 1.3125
# Total reward in episode 31 = 1.875
# Total reward in episode 32 = 2.4375
# Total reward in episode 33 = 1.875
# Total reward in episode 34 = 2.4375
# Total reward in episode 35 = 1.875
# Total reward in episode 36 = 2.625
# Total reward in episode 37 = 1.875
# Total reward in episode 38 = 1.125
# Total reward in episode 39 = 1.5
# Total reward in episode 40 = 1.5
# Total reward in episode 41 = 1.875
# Total reward in episode 42 = 1.3125
# Total reward in episode 43 = 1.5
# Total reward in episode 44 = 1.3125
# Total reward in episode 45 = 1.5
# Total reward in episode 46 = 1.6875
# Total reward in episode 47 = 1.6875
# Total reward in episode 48 = 2.0625
# Total reward in episode 49 = 1.3125
# Total reward in episode 50 = 1.5
# Total reward in episode 51 = 2.25
# Total reward in episode 52 = 1.6875
# Total reward in episode 53 = 1.5
# Total reward in episode 54 = 1.5
# Total reward in episode 55 = 1.125
# Total reward in episode 56 = 2.0625
# Total reward in episode 57 = 1.5
# Total reward in episode 58 = 1.6875
# Total reward in episode 59 = 1.875
# Total reward in episode 60 = 2.625
# Total reward in episode 61 = 2.0625
# Total reward in episode 62 = 1.6875
# Total reward in episode 63 = 1.5
# Total reward in episode 64 = 1.6875
# Total reward in episode 65 = 1.125
# Total reward in episode 66 = 2.0625
# Total reward in episode 67 = 1.875
# Total reward in episode 68 = 0.9375
# Total reward in episode 69 = 1.5
# Total reward in episode 70 = 1.6875
# Total reward in episode 71 = 2.25
# Total reward in episode 72 = 2.25
# Total reward in episode 73 = 1.875
# Total reward in episode 74 = 2.4375
# Total reward in episode 75 = 1.875
# Total reward in episode 76 = 1.5
# Total reward in episode 77 = 1.875
# Total reward in episode 78 = 1.5
# Total reward in episode 79 = 1.6875
# Total reward in episode 80 = 1.5
# Total reward in episode 81 = 1.5
# Total reward in episode 82 = 1.875
# Total reward in episode 83 = 1.5
# Total reward in episode 84 = 2.0625
# Total reward in episode 85 = 2.0625
# Total reward in episode 86 = 1.6875
# Total reward in episode 87 = 2.4375
# Total reward in episode 88 = 1.875
# Total reward in episode 89 = 1.875
# Total reward in episode 90 = 2.0625
# Total reward in episode 91 = 2.25
# Total reward in episode 92 = 1.875
# Total reward in episode 93 = 1.125
# Total reward in episode 94 = 3.0
# Total reward in episode 95 = 1.6875
# Total reward in episode 96 = 1.875
# Total reward in episode 97 = 1.875
# Total reward in episode 98 = 1.5
# Total reward in episode 99 = 1.5
# Total reward in episode 100 = 2.4375
# Total reward in episode 101 = 1.5
# Total reward in episode 102 = 1.875
# Total reward in episode 103 = 2.4375
# Total reward in episode 104 = 2.25
# Total reward in episode 105 = 1.875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 main()
#
# Cell In[3], line 15, in main()
#      12 n_episodes = 1000
#      14 for e in range(n_episodes):
# ---> 15     env.reset()
#      16     terminated = False
#      17     episode_reward = 0
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/smac/env/starcraft2/starcraft2.py:421, in StarCraft2Env.reset(self)
#     418     self.heuristic_targets = [None] * self.n_agents
#     420 try:
# --> 421     self._obs = self._controller.observe()
#     422     self.init_units()
#     423 except (protocol.ProtocolError, protocol.ConnectionError):
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/remote_controller.py:95, in valid_status.<locals>.decorator.<locals>._valid_status(self, *args, **kwargs)
#      91 if self.status not in valid:
#      92   raise protocol.ProtocolError(
#      93       "`%s` called while in state: %s, valid: (%s)" % (
#      94           func.__name__, self.status, ",".join(map(str, valid))))
# ---> 95 return func(self, *args, **kwargs)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/stopwatch.py:205, in StopWatch.decorate.<locals>.decorator.<locals>._stopwatch(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def _stopwatch(*args, **kwargs):
#     204   with self(name):
# --> 205     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/remote_controller.py:244, in RemoteController.observe(self, disable_fog, target_game_loop)
#     240 @valid_status(Status.in_game, Status.in_replay, Status.ended)
#     241 @sw.decorate
#     242 def observe(self, disable_fog=False, target_game_loop=0):
#     243   """Get a current observation."""
# --> 244   obs = self._client.send(observation=sc_pb.RequestObservation(
#     245       game_loop=target_game_loop,
#     246       disable_fog=disable_fog))
#     248   if obs.observation.game_loop == 2**32 - 1:
#     249     logging.info("Received stub observation.")
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/protocol.py:147, in StarcraftProtocol.send(self, **kwargs)
#     145 req.id = next(self._count)
#     146 try:
# --> 147   res = self.send_req(req)
#     148 except ConnectionError as e:
#     149   raise ConnectionError("Error during %s: %s" % (name, e))
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/protocol.py:127, in StarcraftProtocol.send_req(self, request)
#     125 """Write a pre-filled Request and return the Response."""
#     126 self.write(request)
# --> 127 return self.read()
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/stopwatch.py:205, in StopWatch.decorate.<locals>.decorator.<locals>._stopwatch(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def _stopwatch(*args, **kwargs):
#     204   with self(name):
# --> 205     return func(*args, **kwargs)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/protocol.py:98, in StarcraftProtocol.read(self)
#      95   self._log("-------------- [%s] Reading response --------------",
#      96             self._port)
#      97   start = time.time()
# ---> 98 response = self._read()
#      99 if FLAGS.sc2_verbose_protocol:
#     100   self._log("-------------- [%s] Read %s in %0.1f msec --------------\n%s",
#     101             self._port, response.WhichOneof("response"),
#     102             1000 * (time.time() - start), self._packet_str(response))
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/pysc2/lib/protocol.py:179, in StarcraftProtocol._read(self)
#     177 with sw("read_response"):
#     178   with catch_websocket_connection_errors():
# --> 179     response_str = self._sock.recv()
#     180 if not response_str:
#     181   raise ProtocolError("Got an empty response from SC2.")
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_core.py:364, in WebSocket.recv(self)
#     356 """
#     357 Receive string data(byte array) from the server.
#     358
#    (...)
#     361 data: string (byte array) value.
#     362 """
#     363 with self.readlock:
# --> 364     opcode, data = self.recv_data()
#     365 if opcode == ABNF.OPCODE_TEXT:
#     366     return data.decode("utf-8")
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_core.py:387, in WebSocket.recv_data(self, control_frame)
#     372 def recv_data(self, control_frame: bool = False) -> tuple:
#     373     """
#     374     Receive data with operation code.
#     375
#    (...)
#     385         tuple of operation code and string(byte array) value.
#     386     """
# --> 387     opcode, frame = self.recv_data_frame(control_frame)
#     388     return opcode, frame.data
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_core.py:408, in WebSocket.recv_data_frame(self, control_frame)
#     391 """
#     392 Receive data with operation code.
#     393
#    (...)
#     405     tuple of operation code and string(byte array) value.
#     406 """
#     407 while True:
# --> 408     frame = self.recv_frame()
#     409     if (isEnabledForTrace()):
#     410         trace("++Rcv raw: " + repr(frame.format()))
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_core.py:447, in WebSocket.recv_frame(self)
#     439 def recv_frame(self):
#     440     """
#     441     Receive data as frame from server.
#     442
#    (...)
#     445     self.frame_buffer.recv_frame(): ABNF frame object
#     446     """
# --> 447     return self.frame_buffer.recv_frame()
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_abnf.py:340, in frame_buffer.recv_frame(self)
#     337 with self.lock:
#     338     # Header
#     339     if self.has_received_header():
# --> 340         self.recv_header()
#     341     (fin, rsv1, rsv2, rsv3, opcode, has_mask, _) = self.header
#     343     # Frame length
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_abnf.py:296, in frame_buffer.recv_header(self)
#     295 def recv_header(self) -> None:
# --> 296     header = self.recv_strict(2)
#     297     b1 = header[0]
#     298     fin = b1 >> 7 & 1
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_abnf.py:375, in frame_buffer.recv_strict(self, bufsize)
#     367 shortage = bufsize - sum(map(len, self.recv_buffer))
#     368 while shortage > 0:
#     369     # Limit buffer size that we pass to socket.recv() to avoid
#     370     # fragmenting the heap -- the number of bytes recv() actually
#    (...)
#     373     # buffers allocated and then shrunk, which results in
#     374     # fragmentation.
# --> 375     bytes_ = self.recv(min(16384, shortage))
#     376     self.recv_buffer.append(bytes_)
#     377     shortage -= len(bytes_)
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_core.py:531, in WebSocket._recv(self, bufsize)
#     529 def _recv(self, bufsize):
#     530     try:
# --> 531         return recv(self.sock, bufsize)
#     532     except WebSocketConnectionClosedException:
#     533         if self.sock:
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_socket.py:110, in recv(sock, bufsize)
#     108         bytes_ = sock.recv(bufsize)
#     109     else:
# --> 110         bytes_ = _recv()
#     111 except TimeoutError:
#     112     raise WebSocketTimeoutException("Connection timed out")
#
# File ~/anaconda3/envs/rl/lib/python3.11/site-packages/websocket/_socket.py:89, in recv.<locals>._recv()
#      87 def _recv():
#      88     try:
# ---> 89         return sock.recv(bufsize)
#      90     except SSLWantReadError:
#      91         pass
#
# KeyboardInterrupt:
